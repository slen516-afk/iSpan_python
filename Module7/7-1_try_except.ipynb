# %% [markdown]
# ##### try...except...

# %%
# 可以連續定義數個例外處理機制
# 最符合的例外事件類別會先拋出

try:
    num_list = [1, 2]
    print(num_list[2]) #發生錯誤 進入 except
    print(a) #不會執行的區塊
    x = 10   #不會執行的區塊
    print(x) #不會執行的區塊
except Exception as e:  #Exception可以接住大部分的錯誤
    print(f"發生{e}錯誤")


print("程式執行完畢")
# Out:
# 發生list index out of range錯誤
# 程式執行完畢

# %%
# 多層例外處理:

# %% [markdown]
# ##### try...except...else...finally

# %%
# 如果沒有錯誤，就會執行 else 程式區塊
# finally 程式區塊是無論有無錯誤，都會執行
