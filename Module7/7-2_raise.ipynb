# %%
# 自訂例外處理
# 自己定義要什麼樣的錯誤(ValueError, Exception)
x = -1

if x < 0:
    # raise ValueError("資料不能小於0")
    raise Exception("資料不能小於0")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 x = -1
#       5 if x < 0:
#       6     # raise ValueError("資料不能小於0")
# ----> 7     raise Exception("資料不能小於0")
#
# Exception: 資料不能小於0

# %%
# 自訂型別錯誤(TypeError)的例外處理
msg = 100
if type(msg) != str:
    raise TypeError(f"資料必須為字串 使用者傳入了: {type(msg)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 msg = 100
#       3 if type(msg) != str:
# ----> 4     raise TypeError("資料必須為字串")
#
# TypeError: 資料必須為字串

# %% [markdown]
# ##### 設計 raise 陳述
